# %%
import pandas as pd

# %%
df=pd.read_csv('E:/tmdb-movies.csv')

# %%
df
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                      original_title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...

# %% [markdown]
# QUESTION 1

# %% [markdown]
# Which are the movies with third-lowest and third-highest budget?

# %%
df['budget'].nlargest(3)
# Out:
# 2244    425000000
# 3375    380000000
# 7387    300000000
# Name: budget, dtype: int64

# %%
df.iloc[7387]
# Out:
# id                                                                    285
# imdb_id                                                         tt0449088
# popularity                                                        4.96539
# budget                                                          300000000
# revenue                                                         961000000
# original_title                   Pirates of the Caribbean: At World's End
# cast                    Johnny Depp|Orlando Bloom|Keira Knightley|Geof...
# homepage                     http://disney.go.com/disneypictures/pirates/
# director                                                   Gore Verbinski
# tagline                    At the end of the world, the adventure begins.
# keywords                ocean|drug abuse|exotic island|east india trad...
# overview                Captain Barbossa, long believed to be dead, ha...
# runtime                                                               169
# ...

# %%
df['budget'].nsmallest(3)
# Out:
# 30    0
# 36    0
# 72    0
# Name: budget, dtype: int64

# %%
df.iloc[72]
# Out:
# id                                                                 284289
# imdb_id                                                         tt2911668
# popularity                                                        2.27204
# budget                                                                  0
# revenue                                                             45895
# original_title                                           Beyond the Reach
# cast                    Michael Douglas|Jeremy Irvine|Hanna Mangan Law...
# homepage                                                              NaN
# director                                          Jean-Baptiste L̩onetti
# tagline                                                               NaN
# keywords                                                   desert|hunting
# overview                A high-rolling corporate shark and his impover...
# runtime                                                                95
# ...

# %% [raw]
# Ans: Third-lowest  : Beyond the Reach - 0,
#      Third-highest : Pirates of the Caribbean: At World's End - 300000000

# %% [markdown]
# QUESTION 2

# %% [markdown]
# What is the average number of words in movie titles between the years 2000 - 2005 ?

# %%
df1=pd.read_csv('E:/tmdb-movies.csv')

# %%
q_2 = df1[(df1['release_year']>=2000) & (df1['release_year']<2005)]

# %%
q_2
# Out:
#          id    imdb_id  popularity     budget    revenue  \
# 2633    120  tt0120737    8.575419   93000000  871368364
# 2634    671  tt0241527    8.021423  125000000  976475550
# 2635   1018  tt0166924    4.436367   15000000   20117339
# 2636    141  tt0246578    3.851009    6000000    1270522
# 2637    585  tt0198781    3.204295  115000000  562816256
# ...     ...        ...         ...        ...        ...
# 8883  36047  tt0163676    0.015997   15000000    5217498
# 8884  97351  tt0222270    0.006865          0          0
# 8885  20438  tt0234853    0.005784          0          0
# 8886  18292  tt0262432    0.080819          0          0
# 8887  44756  tt0250440    0.004010          0          0
#
#                                          original_title  \
# 2633  The Lord of the Rings: The Fellowship of the Ring
# 2634           Harry Potter and the Philosopher's Stone
# 2635                                   Mulholland Drive
# ...

# %%
words= q_2['original_title'].str.split().str.len()

# %%
words
# Out:
# 2633    10
# 2634     6
# 2635     2
# 2636     2
# 2637     2
#         ..
# 8883     3
# 8884     5
# 8885     4
# 8886     2
# 8887     4
# Name: original_title, Length: 1323, dtype: int64

# %%
words.mean()
# Out:
# 2.876039304610733

# %% [raw]
# Ans : 2.876039304610733

# %% [markdown]
# QUESTION 3

# %% [markdown]
# Which are the movies with the most and least earned revenue?

# %%
df['revenue'].nlargest(1)
# Out:
# 1386    2781505847
# Name: revenue, dtype: int64

# %%
df.iloc[1386]
# Out:
# id                                                                  19995
# imdb_id                                                         tt0499549
# popularity                                                        9.43277
# budget                                                          237000000
# revenue                                                        2781505847
# original_title                                                     Avatar
# cast                    Sam Worthington|Zoe Saldana|Sigourney Weaver|S...
# homepage                                      http://www.avatarmovie.com/
# director                                                    James Cameron
# tagline                                       Enter the World of Pandora.
# keywords                culture clash|future|space war|space colony|so...
# overview                In the 22nd century, a paraplegic Marine is di...
# runtime                                                               162
# ...

# %%
df['revenue'].nsmallest(1)
# Out:
# 48    0
# Name: revenue, dtype: int64

# %%
df.iloc[48]
# Out:
# id                                                                 265208
# imdb_id                                                         tt2231253
# popularity                                                        2.93234
# budget                                                           30000000
# revenue                                                                 0
# original_title                                                  Wild Card
# cast                    Jason Statham|Michael Angarano|Milo Ventimigli...
# homepage                                                              NaN
# director                                                       Simon West
# tagline                       Never bet against a man with a killer hand.
# keywords                                        gambling|bodyguard|remake
# overview                When a Las Vegas bodyguard with lethal skills ...
# runtime                                                                92
# ...

# %% [raw]
# Ans: Most Revenue - Avatar (2781505847)
#      Least Revenue - Wild Card(0)

# %% [markdown]
# QUESTION 4

# %% [markdown]
# What is the average runtime of movies in the year 2006?

# %%
var1=df[df['release_year']==2006]

# %%
var1
# Out:
#          id    imdb_id  popularity     budget     revenue  \
# 6554    834  tt0401855    5.838503   50000000   111340801
# 6555     58  tt0383574    4.205992  200000000  1065659812
# 6556    920  tt0317219    3.941265  120000000   461983149
# 6557  36557  tt0381061    3.789580  150000000   599045960
# 6558    591  tt0382625    3.655536  125000000   758239851
# ...     ...        ...         ...        ...         ...
# 6957    286  tt0853060    0.013578          0           0
# 6958  33753  tt0457936    0.012132          0           0
# 6959  24115  tt0462346    0.153217          0    13022756
# 6960  20605  tt0821470    0.005412    2700000           0
# 6961  15412  tt0466460    0.001115          0           0
#
#                                   original_title  \
# 6554                       Underworld: Evolution
# 6555  Pirates of the Caribbean: Dead Man's Chest
# 6556                                        Cars
# 6557                               Casino Royale
# ...

# %%
var1['runtime'].mean()
# Out:
# 101.68382352941177

# %% [raw]
# Ans : Average runtime - 101.68382352941177
